# %%
import pandas as pd
import numpy as np
print(pd.__version__)
print(np.__version__)
# Out:
# 3.0.6
# 2.5.3

# %%
my_array = np.array([1,2,3,4])
average = np.mean(my_array)
print(average)
# Out:
# 2.5
